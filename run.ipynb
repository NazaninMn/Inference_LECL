# %%
from os import chdir as cd
# !chmod u+x run_tile.sh

# %%
# !python main.py --nuclei_channel_image 3 --marker_channel_image 4 --root /home/nm4wu/ --test_list 90985-19B.tif --marker_name TdTom

#EdU 1
#GFP 2 
# TdTom 4

# %%
# !python integration.py --root /home/nm4wu --img_name 20X_90985-19B.tif.csv --list_markers_name TdTom,GFP,EdU

#EdU 1
#GFP 2 
# TdTom 4
# Out:
# integration.py:36: DeprecationWarning: Please use `label` from the `scipy.ndimage` namespace, the `scipy.ndimage.measurements` namespace is deprecated.
#   label,N = measurements.label(integrated)
# integration.py:42: DeprecationWarning: Please use `label` from the `scipy.ndimage` namespace, the `scipy.ndimage.measurements` namespace is deprecated.
#   label,N = measurements.label(integrated)
# 92.900381565094
